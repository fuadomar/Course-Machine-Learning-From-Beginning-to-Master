# %%
# !pip install numpy pandas scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: pandas in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (2.3.0)
# Requirement already satisfied: scikit-learn in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: matplotlib in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: seaborn in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /home/nahid/anaconda3/envs/ec_rnd_final/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = load_iris()

X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = iris.target

feature_names = iris.feature_names
target_names = iris.target_names

print("Dataset Shape:", X.shape)
print("Feature Names:", feature_names)
print("Target Names:", target_names)
# Out:
# Dataset Shape: (150, 4)
# Feature Names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target Names: ['setosa' 'versicolor' 'virginica']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# %%
n_samples = X_train.shape[0]

print(n_samples)
indices = np.random.choice(n_samples, size=n_samples, replace=True)

X_boot = X_train.iloc[indices]
y_boot = y_train[indices]

print("Bootstrap Sample Indices (first 10):", indices[:10])
print("Bootstrap Sample Shape:", X_boot.shape)
# Out:
# 105
# Bootstrap Sample Indices (first 10): [ 90  65  67  91  38 104  91  96   4  60]
# Bootstrap Sample Shape: (105, 4)

# %%
rf_model = RandomForestClassifier(
    n_estimators=100,
    max_features='sqrt',
    bootstrap=True,
    random_state=42,
    n_jobs=-1
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
y_pred = rf_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8889

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.78      0.93      0.85        15
#    virginica       0.92      0.73      0.81        15
#
#     accuracy                           0.89        45
#    macro avg       0.90      0.89      0.89        45
# weighted avg       0.90      0.89      0.89        45

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
importances = rf_model.feature_importances_
indices = np.argsort(importances)[::-1]


plt.figure(figsize=(10, 6))
plt.title("Feature Importance")
plt.bar(range(len(feature_names)), importances[indices], align='center')
plt.xticks(range(len(feature_names)), [feature_names[i] for i in indices], rotation=45)
plt.xlabel("Features")
plt.ylabel("Importance")
plt.tight_layout()
plt.show()
